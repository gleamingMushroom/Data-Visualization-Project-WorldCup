# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd

# %%
import csv

# %%
GDP  = pd.read_csv('/Users/Mushroom/Downloads/viz_datasets/TeamProject/GDP_currentUS.csv',sep=',',skiprows=4)

# %%
worldcup = pd.read_csv('/Users/Mushroom/Downloads/viz_datasets/TeamProject/WorldCups.csv')

# %%
GDP.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
worldcup.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17        363
# 2           84              15             18      375.7
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
len(worldcup)
# Out:
# 21

# %%
GDP = GDP.rename(columns={'Country Name': 'Country'})

# %%
worldcupGDP = worldcup.merge(GDP, how='left')

# %%
worldcupGDP.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance     ...       \
# 0           70              13             18    590.549     ...
# 1           70              16             17        363     ...
# 2           84              15             18      375.7     ...
# 3           88              13             22  1.045.246     ...
# 4          140              16             26    768.607     ...
#
#            2009          2010          2011          2012          2013  \
# 0  3.166091e+10  4.028448e+10  4.796244e+10  5.126439e+10  5.753123e+10
# ...

# %%
worldcupGDP.isnull().sum()
# Out:
# Year               0
# Country            0
# Winner             0
# Runners-Up         0
# Third              0
# Fourth             0
# GoalsScored        0
# QualifiedTeams     0
# MatchesPlayed      0
# Attendance         0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1960               3
# 1961               3
# 1962               2
# 1963               2
# 1964               2
# 1965               2
# 1966               2
# 1967               2
# 1968               2
# 1969               2
# 1970               1
# 1971               1
# 1972               1
# 1973               1
# 1974               1
# 1975               1
# 1976               1
#                   ..
# 1989               0
# 1990               0
# 1991               0
# 1992               0
# 1993               0
# 1994               0
# 1995               0
# 1996               0
# 1997               0
# 1998               0
# 1999               0
# 2000               0
# ...

# %%
worldcupGDP = worldcupGDP.drop(['2017', 'Unnamed: 62'], axis=1)

# %%
worldcupGDP.to_csv('worldcupGDP.csv')

# %%
GDP_growth  = pd.read_csv('/Users/Mushroom/Downloads/viz_datasets/TeamProject/GDP growth.csv',sep=',',skiprows=4)

# %%
GDP_growth.head()
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965     ...            2009      2010      2011  \
# 0   NaN   NaN   NaN   NaN   NaN     ...       -5.653502       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...       21.020649  8.433290  6.113685
# 2   NaN   NaN   NaN   NaN   NaN     ...        2.412870  3.407655  3.918597
# 3   NaN   NaN   NaN   NaN   NaN     ...        3.352610  3.710058  2.550161
# 4   NaN   NaN   NaN   NaN   NaN     ...       -3.690654 -5.358826 -4.646543
#
# ...

# %%
GDP_growth = GDP_growth.rename(columns={'Country Name': 'Country'})

# %%
worldcupGDPGrowth = worldcup.merge(GDP_growth, how='left')

# %%
worldcupGDPGrowth.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance     ...       \
# 0           70              13             18    590.549     ...
# 1           70              16             17        363     ...
# 2           84              15             18      375.7     ...
# 3           88              13             22  1.045.246     ...
# 4          140              16             26    768.607     ...
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0  4.243494  7.803410  5.162133  3.538179  4.637539  3.238791  0.370741
# ...

# %%
worldcupGDPGrowth.isnull().sum()
# Out:
# Year               0
# Country            0
# Winner             0
# Runners-Up         0
# Third              0
# Fourth             0
# GoalsScored        0
# QualifiedTeams     0
# MatchesPlayed      0
# Attendance         0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1960              21
# 1961               3
# 1962               3
# 1963               3
# 1964               3
# 1965               3
# 1966               3
# 1967               3
# 1968               3
# 1969               3
# 1970               3
# 1971               1
# 1972               1
# 1973               1
# 1974               1
# 1975               1
# 1976               1
#                   ..
# 1989               0
# 1990               0
# 1991               0
# 1992               0
# 1993               0
# 1994               0
# 1995               0
# 1996               0
# 1997               0
# 1998               0
# 1999               0
# 2000               0
# ...

# %%
worldcupGDPGrowth = worldcupGDPGrowth.drop(['2017', 'Unnamed: 62'], axis=1)

# %%
worldcupGDPGrowth.to_csv('worldcupGDPGrowth.csv')
